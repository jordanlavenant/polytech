# %% [markdown]
# ###### Polytech Paris-Saclay | 3e année
#
# # TP5 Algo-Num-1 : Algorithmme de Thomas

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sla

# %%
N = 4

# %% [markdown]
# ## Génération matrice $A$

# %%
A = (np.eye(N) * -2) + (np.eye(N, k=1)) + (np.eye(N, k=-1))

# %% [markdown]
# ## Descente $T$

# %% [markdown]
# ## Montée $T$
